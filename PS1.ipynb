# %% [markdown]
# <a href="https://colab.research.google.com/github/citjimm/DMDS/blob/main/PS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr
from pandas_datareader import wb
from pandas.io.formats.style import Styler
import matplotlib.pyplot as plt

# %%
#!wget -q -O edad.xlsx https://raw.githubusercontent.com/citjim/raw/main/edad.xlsx #aok no it doesnt work
# !wget -q -O edad.xlsx https://github.com/citjimm/DMDS/raw/main/edad.xlsx
#https://github.com/citjimm/DMDS/raw/main/edad.xlsx
pd.read_excel('edad.xlsx') #aok misspelled here
#and read in the right chunk; or rename var to sth meaningful and drop rows that are junk
# see links on excel in class notebook
# Out:
#    Table EDAd. Emergency department visits within the past 12 months among adults aged 18 and over, by selected characteristics: United States, selected years 1997–2019  \
# 0   Excel version (with more data years and standa...
# 1   [Data are based on household interviews of a s...
# 2                                      Characteristic
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 72                                         Within MSA
# 73                                        Outside MSA
# 74  … Category not applicable.\n* Estimates are co...
# 75  NOTES: Respondents were asked, "During the pas...
# 76  SOURCE: National Center for Health Statistics,...
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# ...

# %%
#aok: breaks again: no such file
# !wget -q -O edad.csv https://drive.google.com/uc?id=1wEs1JH2J5r3JR4IIkoWqUsfYbcb_0S26/&export=download

#https://drive.google.com/file/d/1wEs1JH2J5r3JR4IIkoWqUsfYbcb_0S26/view?usp=drive_link
#pd.read_excel ('https://drive.google.com/uc?id=1fSLZfISAbn_jYF5f9I6t5Y3mx0WAiVMd/&export=download')

pd.read_csv ('edad.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-5-84c42836c4fb> in <cell line: 6>()
#       4 #pd.read_excel ('https://drive.google.com/uc?id=1fSLZfISAbn_jYF5f9I6t5Y3mx0WAiVMd/&export=download')
#       5
# ----> 6 pd.read_csv ('edad.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# Census Data- HTML - Wikipedia

# %%
import html
#dt=
pd.read_html('https://en.wikipedia.org/wiki/2020_United_States_census',match='Change',flavor=None)[0].head(52)

dat= pd.read_html('https://en.wikipedia.org/wiki/2020_United_States_census',match='Change',flavor=None)[0].head(52)

dat

dat.columns

dat.describe()

dat.Change

dat

#state_changes = dat[['State','Change']]





#Was attempting to use to creat bar graph of change


#state_changes.plot(kind='bar', x='State', y='Change', figsize=(12, 8), legend=False)
#plt.xlabel('State')
#plt.ylabel('Population change')
#plt.title('Percent change in population by State (2020 Census)')
#plt.xticks(rotation=90)  # Rotate state labels for better readability
#plt.show()
# Out:
#    Rank                 State  Population as of 2020 census[85]  \
# 0     1            California                          39538223
# 1     2                 Texas                          29145505
# 2     3               Florida                          21538187
# 3     4              New York                          20201249
# 4     5          Pennsylvania                          13002700
# 5     6              Illinois                          12812508
# 6     7                  Ohio                          11799448
# 7     8               Georgia                          10711908
# 8     9        North Carolina                          10439388
# 9    10              Michigan                          10077331
# 10   11            New Jersey                           9288994
# 11   12              Virginia                           8631393
# 12   13            Washington                           7705281
# 13   14               Arizona                           7151502
# ...

# %% [markdown]
# Is there an issue with the data set itself?
#
# aok: looks fine

# %%
# !wget -q -O index.json https://drive.google.com/uc?id=16JKCFx676wzEvz8ZmNlgmWqpbD-qWDDT/&export=download
#aok no it doesnt load--if you put that url into webbrowser it doesnt exist
data= pd.read_json('index.json', lines=True)

# lines= true (from stack overflow) seems to have helped but then...

data.columns
#is there a problem in uploading the data???
# Out:
# Float64Index([], dtype='float64')

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []
